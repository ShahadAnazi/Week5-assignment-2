# %%
pip install "jupyterlab>=3" "ipywidgets>=7.6" "plotly==5.3.1" "cufflinks"
# Out:
# Requirement already satisfied: jupyterlab>=3 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (3.0.14)
# Requirement already satisfied: ipywidgets>=7.6 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (7.6.3)
# Requirement already satisfied: plotly==5.3.1 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (5.3.1)
# Requirement already satisfied: cufflinks in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (0.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from plotly==5.3.1) (8.0.1)
# Requirement already satisfied: six in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from plotly==5.3.1) (1.15.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.6) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.6) (1.0.0)
# Requirement already satisfied: ipython>=4.0.0 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.6) (7.22.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.6) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.6) (5.3.4)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.6) (5.0.5)
# Requirement already satisfied: packaging in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from jupyterlab>=3) (20.9)
# Requirement already satisfied: tornado>=6.1.0 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from jupyterlab>=3) (6.1)
# Requirement already satisfied: jupyter-server~=1.4 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from jupyterlab>=3) (1.4.1)
# Requirement already satisfied: nbclassic~=0.2 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from jupyterlab>=3) (0.2.6)
# Requirement already satisfied: jupyter-core in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from jupyterlab>=3) (4.7.1)
# Requirement already satisfied: jupyterlab-server~=2.3 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from jupyterlab>=3) (2.4.0)
# Requirement already satisfied: jupyter-packaging~=0.7 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from jupyterlab>=3) (0.7.12)
# Requirement already satisfied: jinja2>=2.10 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from jupyterlab>=3) (2.11.3)
# Requirement already satisfied: appnope in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6) (0.1.2)
# Requirement already satisfied: jupyter-client in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6) (6.1.12)
# Requirement already satisfied: backcall in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.6) (0.2.0)
# Requirement already satisfied: decorator in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.6) (5.0.6)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.6) (3.0.17)
# Requirement already satisfied: setuptools>=18.5 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.6) (52.0.0.post20210125)
# Requirement already satisfied: pygments in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.6) (2.8.1)
# Requirement already satisfied: pickleshare in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.6) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.6) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.6) (0.17.2)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.6) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from jinja2>=2.10->jupyterlab>=3) (1.1.1)
# Requirement already satisfied: Send2Trash in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab>=3) (1.5.0)
# Requirement already satisfied: anyio>=2.0.2 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab>=3) (2.2.0)
# Requirement already satisfied: prometheus-client in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab>=3) (0.10.1)
# Requirement already satisfied: ipython-genutils in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab>=3) (0.2.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab>=3) (0.9.4)
# Requirement already satisfied: pyzmq>=17 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab>=3) (20.0.0)
# Requirement already satisfied: nbconvert in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab>=3) (6.0.7)
# Requirement already satisfied: sniffio>=1.1 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from anyio>=2.0.2->jupyter-server~=1.4->jupyterlab>=3) (1.2.0)
# Requirement already satisfied: idna>=2.8 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from anyio>=2.0.2->jupyter-server~=1.4->jupyterlab>=3) (2.10)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.6) (2.8.1)
# Requirement already satisfied: jsonschema>=3.0.1 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from jupyterlab-server~=2.3->jupyterlab>=3) (3.2.0)
# Requirement already satisfied: babel in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from jupyterlab-server~=2.3->jupyterlab>=3) (2.9.0)
# Requirement already satisfied: requests in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from jupyterlab-server~=2.3->jupyterlab>=3) (2.25.1)
# Requirement already satisfied: json5 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from jupyterlab-server~=2.3->jupyterlab>=3) (0.9.5)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab>=3) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab>=3) (20.3.0)
# Requirement already satisfied: notebook<7 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from nbclassic~=0.2->jupyterlab>=3) (6.3.0)
# Requirement already satisfied: argon2-cffi in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from notebook<7->nbclassic~=0.2->jupyterlab>=3) (20.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.6) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.6) (0.2.5)
# Requirement already satisfied: colorlover>=0.2 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: pandas in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from cufflinks) (1.2.4)
# Requirement already satisfied: cffi>=1.0.0 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from argon2-cffi->notebook<7->nbclassic~=0.2->jupyterlab>=3) (1.14.5)
# Requirement already satisfied: pycparser in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook<7->nbclassic~=0.2->jupyterlab>=3) (2.20)
# Requirement already satisfied: pytz>=2015.7 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from babel->jupyterlab-server~=2.3->jupyterlab>=3) (2021.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3) (0.5.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3) (0.1.2)
# Requirement already satisfied: bleach in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3) (3.3.0)
# Requirement already satisfied: defusedxml in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3) (0.7.1)
# Requirement already satisfied: testpath in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3) (0.4.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3) (1.4.3)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3) (0.3)
# Requirement already satisfied: nest-asyncio in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter-server~=1.4->jupyterlab>=3) (1.5.1)
# Requirement already satisfied: async-generator in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter-server~=1.4->jupyterlab>=3) (1.10)
# Requirement already satisfied: webencodings in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert->jupyter-server~=1.4->jupyterlab>=3) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from packaging->jupyterlab>=3) (2.4.7)
# Requirement already satisfied: numpy>=1.16.5 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from pandas->cufflinks) (1.20.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from requests->jupyterlab-server~=2.3->jupyterlab>=3) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from requests->jupyterlab-server~=2.3->jupyterlab>=3) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/shahad/opt/anaconda3/lib/python3.8/site-packages (from requests->jupyterlab-server~=2.3->jupyterlab>=3) (4.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance
import numpy as np
import pandas as pd
import pandas
import yfinance as yf
from pandas_datareader import data as pdr
yf.pdr_override()

# %%
#import cufflinks as cf
#cf.set_config_file(offline=True)

from chart_studio import plotly


import warnings
warnings.filterwarnings("ignore")

# %%
from ActMng import AccountManager

# %%
starting_capital = 100000
allocation = 0.8

symbol = 'SPY'

long_trend_days = 12
short_trend_days = 6

# %%
def fetch_data(symbol:str='SPY', start_date:str='2020', end_date:str=None):
    
    if end_date is None:
        end = pandas.Timestamp.now()
    else:
        end = end_date
    
    return pdr.get_data_yahoo(symbol, pandas.Timestamp(start_date), pandas.Timestamp(end))[['Open','Close']]
df = fetch_data(symbol)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
fast_trend = df.Open.rolling(window=short_trend_days).mean()
slow_trend = df.Open.rolling(window=long_trend_days).mean()

df['ma_fast'] = fast_trend
df['ma_slow'] = slow_trend
df[['Close','ma_fast','ma_slow']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['trade_direction'] = np.sign(fast_trend-slow_trend)
df
# Out:
#                   Open       Close     ma_fast     ma_slow  trade_direction
# Date
# 2019-12-31  320.529999  321.859985         NaN         NaN              NaN
# 2020-01-02  323.540009  324.869995         NaN         NaN              NaN
# 2020-01-03  321.160004  322.410004         NaN         NaN              NaN
# 2020-01-06  320.489990  323.640015         NaN         NaN              NaN
# 2020-01-07  323.019989  322.730011         NaN         NaN              NaN
# ...                ...         ...         ...         ...              ...
# 2021-11-08  469.700012  468.929993  464.359996  459.879166              1.0
# 2021-11-09  469.320007  467.380005  465.863332  461.228333              1.0
# 2021-11-10  465.579987  463.619995  466.756663  462.169998              1.0
# 2021-11-11  465.209991  463.769989  467.408330  462.837496              1.0
# 2021-11-12  465.119995  467.269989  467.368332  463.559995              1.0
#
# [473 rows x 5 columns]

# %%
#Determine the direction of the moving average differences
df_trades = df['trade_direction'].dropna().diff().dropna().apply(np.sign).astype('int8')
df_trades = pandas.DataFrame(df_trades[df_trades !=0])

#Label our intended trades
df_trades['trade'] = df['trade_direction'].map({1:'Long',-1:'Short'})
df['trades'] = df_trades['trade']

# %%
#Label our opening trade after removing our window period
df['trades'].replace(pandas.np.NaN,'None',inplace=True)
df = df.dropna()
df['trades'].iloc[0]=('Long' if df['trade_direction'].iloc[0]==1.0 else 'Short')
df
# Out:
#                   Open       Close     ma_fast     ma_slow  trade_direction  \
# Date
# 2020-02-03  323.350006  324.119995  325.196665  328.232501             -1.0
# 2020-02-04  328.070007  329.059998  326.036667  328.096667             -1.0
# 2020-02-05  332.269989  332.859985  327.238332  328.144165             -1.0
# 2020-02-06  333.910004  333.980011  328.159999  328.394999             -1.0
# 2020-02-07  332.820007  332.200012  329.570002  328.443334              1.0
# ...                ...         ...         ...         ...              ...
# 2021-11-08  469.700012  468.929993  464.359996  459.879166              1.0
# 2021-11-09  469.320007  467.380005  465.863332  461.228333              1.0
# 2021-11-10  465.579987  463.619995  466.756663  462.169998              1.0
# 2021-11-11  465.209991  463.769989  467.408330  462.837496              1.0
# 2021-11-12  465.119995  467.269989  467.368332  463.559995              1.0
#
#            trades
# Date
# 2020-02-03  Short
# 2020-02-04   None
# 2020-02-05   None
# 2020-02-06   None
# 2020-02-07   Long
# ...           ...
# 2021-11-08   None
# 2021-11-09   None
# 2021-11-10   None
# 2021-11-11   None
# 2021-11-12   Long
#
# [451 rows x 6 columns]

# %%
# Our trading strategy implementation - feel free to brose ActMng.py if you are curious.
trading_strategy = AccountManager(symbol=symbol,trades_df=df,starting_capital=starting_capital,allocation_amount=allocation)
results = trading_strategy.run()

# %%
#Here we can see a day by day breakdown of the account
results['result_df']
# Out:
#                   Open       Close     ma_fast     ma_slow  trade_direction  \
# 2020-01-16  329.700012  330.920013  327.393341  324.670003              1.0
# 2020-01-17  331.700012  331.950012  328.316676  325.600838              1.0
# 2020-01-21  330.899994  331.299988  328.918340  326.214170              1.0
# 2020-01-22  332.239990  331.339996  329.893336  327.137502              1.0
# 2020-01-23  330.630005  331.720001  330.420003  327.982503              1.0
# ...                ...         ...         ...         ...              ...
# 2021-11-08  469.700012  468.929993  464.359996  459.879166              1.0
# 2021-11-09  469.320007  467.380005  465.863332  461.228333              1.0
# 2021-11-10  465.579987  463.619995  466.756663  462.169998              1.0
# 2021-11-11  465.209991  463.769989  467.408330  462.837496              1.0
# 2021-11-12  465.119995  467.269989  467.368332  463.559995              1.0
#
#            trades    account_val       cash_bal  position  position_changes  \
# 2020-01-16   Long  100295.021096   20000.589038    242.64            242.64
# 2020-01-17   None  100544.940000   20000.589038    242.64              0.00
# 2020-01-21   None  100387.218076   20000.589038    242.64              0.00
# 2020-01-22   None  100396.925750   20000.589038    242.64              0.00
# 2020-01-23   None  100489.130134   20000.589038    242.64              0.00
# ...           ...            ...            ...       ...               ...
# 2021-11-08   None  136505.079669   25682.854500    236.33              0.00
# 2021-11-09   None  136138.771054   25682.854500    236.33              0.00
# 2021-11-10   None  135250.167946   25682.854500    236.33              0.00
# 2021-11-11   None  135285.616004   25682.854500    236.33              0.00
# 2021-11-12  Short  136112.771004  136111.771004      0.00           -236.33
#
#             fees
# 2020-01-16   1.0
# 2020-01-17   0.0
# 2020-01-21   0.0
# 2020-01-22   0.0
# 2020-01-23   0.0
# ...          ...
# 2021-11-08   0.0
# 2021-11-09   0.0
# 2021-11-10   0.0
# 2021-11-11   0.0
# 2021-11-12   1.0
#
# [462 rows x 11 columns]

# %%
# Here are our simulated orders as we would submit to an API endpoint for algorthmic trading. 
results['broker_orders']
# Out:
#            symbol                 date             time order order_type  \
# 2020-01-16    SPY  2020-01-16 00:00:00   At Market Open   BUY     MARKET
# 2020-01-29    SPY  2020-01-29 00:00:00   At Market Open  SELL     MARKET
# 2020-01-29    SPY  2020-01-29 00:00:00   At Market Open  SELL     MARKET
# 2020-02-07    SPY  2020-02-07 00:00:00   At Market Open   BUY     MARKET
# 2020-02-07    SPY  2020-02-07 00:00:00   At Market Open   BUY     MARKET
# ...           ...                  ...              ...   ...        ...
# 2021-09-14    SPY  2021-09-14 00:00:00   At Market Open  SELL     MARKET
# 2021-09-14    SPY  2021-09-14 00:00:00   At Market Open  SELL     MARKET
# 2021-10-13    SPY  2021-10-13 00:00:00   At Market Open   BUY     MARKET
# 2021-10-13    SPY  2021-10-13 00:00:00   At Market Open   BUY     MARKET
# 2021-11-12    SPY  2021-11-12 00:00:00  At Market Close  SELL     MARKET
#
#                  price    size  exchange_fees
# 2020-01-16  329.700012  242.64            1.0
# 2020-01-29  328.380005  242.64            1.0
# 2020-01-29  328.380005  242.84            1.0
# 2020-02-07  332.820007  242.84            1.0
# 2020-02-07  332.820007  237.00            1.0
# ...                ...     ...            ...
# 2021-09-14  448.119995  223.86            1.0
# 2021-09-14  448.119995  223.90            1.0
# 2021-10-13  434.709991  223.90            1.0
# 2021-10-13  434.709991  236.33            1.0
# 2021-11-12  467.269989  236.33            1.0
#
# [66 rows x 8 columns]

# %%
#Todo:
r_df = results["result_df"]
# Calculate the Absolute Return of our trend-following trading strategy
absolute_return_tf = (r_df['account_val'].iloc[-1]-starting_capital)/starting_capital
print(f"Absolute_return_tf: % {np.round(absolute_return_tf,2)*100}")

# Calculate the CAGR or our trend-following trading strategy
CAGR_tf = ((r_df['account_val'].iloc[-1]/starting_capital)**(252/len(df)))-1
print(f"CAGR_tf: %{np.round(CAGR_tf,2)*100}")

# Calculate the IR (Sharpe without RF-rate) of our trend-following trading strategy
information_ratio_tf = r_df.account_val.pct_change().mean()/r_df.account_val.pct_change().std()
print(f"information_ratio_tf: {np.round(information_ratio_tf,4)}")
#Plot the equity curve (hint: use 'account_val')
r_df.account_val.plot()
# Out:
# Absolute_return_tf: % 36.0
# CAGR_tf: %18.0
# information_ratio_tf: 0.0636
# <AxesSubplot:>

# %%
#Todo:
# Calculate the Absolute Return of a buy-and-hold strategy in the same period
absolute_return_bh = (r_df.Close.iloc[-1]-r_df.Open.iloc[0])/r_df.Open.iloc[0]*100

# Calculate the CAGR or our trend-following trading strategy
CAGR_bh = ((r_df.Close.iloc[-1]/r_df.Close.iloc[0])**(365/(r_df.index[-1]- r_df.index[0]).days))-1

# Calculate the IR (Sharpe without RF-rate) of our trend-following trading strategy
information_ratio_bh = (r_df.Close.pct_change().mean()/r_df.Close.pct_change().std())*((252)**0.5)

#Plot the equity curve (hint: use 'close' returns and your initial capital value to generate an equity curve)
((r_df.Close.pct_change().dropna()+1).cumprod()*starting_capital).plot()
# Out:
# <AxesSubplot:>

# %%
#Todo - optional, below:
# Copy any of the code from above to new cells below, and see how changing the symbol, dates and trend parameters changes the performance
# Can you beat the reference implementation?
